# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 8
# ---------------------------------------
#
# GOALS:
#
# 1. Load data into Python that you find online
# 2. Understand data types and fix some errors
# 3. Find your own data to play with
#
# ----------------------------------------------------------
#
# This homework has **5 questions** and **1 problem**.
#
# NOTE: Be kind to yourself. Working with data can be hard! Every data set is different. **Seriously** come get help! Come to lab!

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %% [markdown]
# ## Try reading in some data - csv
#
# Go to the [Cal Fire Website](https://www.fire.ca.gov/incidents) and scroll to the bottom to see the Incident Data. We will download the file named **ALL DATA AS CSV** this should put the data file into your Downloads folder.
#
# Next you need to move the file **mapdataall.csv** from your Downloads folder into your Day8 folder where you are doing your homework. You can open your Downloads folder and drag the file into JupyterLab side bar. Then I can run the command
#
#     DF_raw = pd.read_csv('mapdataall.csv')
#
# to load the data and look at the data frame.

# %%
# Your code here
DF_raw = pd.read_csv('mapdataall.csv')
DF_raw
# Out:
#       incident_name incident_is_final  incident_date_last_update  \
# 0       Bridge Fire                 Y       2018-01-09T13:46:00Z
# 1         Pala Fire                 Y       2020-09-16T14:07:35Z
# 2        River Fire                 Y       2022-10-24T11:39:23Z
# 3     Fawnskin Fire                 Y       2013-04-22T09:00:00Z
# 4         Gold Fire                 Y       2013-05-01T07:00:00Z
# ...             ...               ...                        ...
# 2739  Two Mile Fire                 Y       2024-10-06T10:11:56Z
# 2740   Tuledad Fire                 N  2024-10-07T07:20:30-07:00
# 2741   Hambone Fire                 N       2024-10-07T08:46:35Z
# 2742  Verjeles Fire                 N       2024-10-07T08:57:16Z
# 2743      Wood Fire                 N       2024-10-07T08:57:24Z
#
#      incident_date_created          incident_administrative_unit  \
# 0     2017-10-31T11:22:00Z       Shasta-Trinity National Forest
# ...

# %% [markdown]
# **Q1** How many variables and observations?
#
# **Q2** How many different incident types are there?
#
# **Q3** Make a histogram of the acres burned and color the bars by whether or not the incident was a calfire incident. You will probably need to make a mask to remove very small and very large fires. How many fires burned more than 100,000 acres? What is the largest fire in the data?
#
# **Extra Q** EXTRA - CHALLENGE - See if you can create a graph that answers the question: Are fires getting bigger or more frequent over time? You get complete creative control on how to answer this question!

# %%
# You will need to write some code to answer the questions.
#Q1
DF_raw.shape
# Out:
# (2744, 23)

# %% [markdown]
# This data has 2744 observations and 23 variables

# %%
# Extra Code
#Q2
columns=['incident_name', 'incident_type']
DF_raw[columns].groupby('incident_type').sum()
# Out:
#                                                    incident_name
# incident_type
# Fire           Refuge FireLine FireWestwood FireLuis FireCoyo...
# Flood                                             Honey Flooding
# Wildfire       Pala FireSand FireWragg FireButte FireAtlas Fi...

# %% [markdown]
# **Q2**In this code above I tried to find the type of incidents using groupby, and then I foucused on the columns 'incident_name' and 'incident_type', so there is 3 types of insidents in my data.

# %%
#Q3 Make a histogram of the acres burned and color the bars
#by whether or not the incident was a calfire incident.
#You will probably need to make a mask to remove very small
#and very large fires. How many fires burned more than 100,000 acres?
#What is the largest fire in the data?

fig = px.histogram(
                  DF_raw,
                  x='incident_acres_burned',
                  y='calfire_incident',
                  nbins= 6)
fig.update_layout(bargap=0.1,
                  title='Histogram of acres burned.')
mask = (DF_raw['calfire_incident'])
fig.show()

# %% [markdown]
# In this histogram I used my X as 'incident_acres_burned' ans for my Y I used 'calfire_incident', so then my histogram showed me if the acres burned where a calfire incident or not

# %%
#Extra Q EXTRA - CHALLENGE - See if you can create a graph that answers the question:
#Are fires getting bigger or more frequent over time? 
#You get complete creative control on how to answer this question!

#my_columns = ['incident_dateonly_created', 'is_active', 'incident_dateonly_extinguished']
#DF_raw[my_columns].sort_values('incident_dateonly_created')

fig = px.histogram(DF_raw,
                   x='incident_date_last_update',
                   labels={'incident_acres_burned':'incident_acres_burned'},
                   color_discrete_sequence=['red'])
fig.update_layout(bargap=0.3, title=
            'Are fires getting bigger or more frequent over time?',
            title_x=0.9)
fig.show()

# %% [markdown]
# In the code below I used 2 columns: 'incident_date_last_update'and 'incident_acres_burned', so then I can see how frecuent the fires are over the years.
# We can see in the graph how the incidents increased from 2018 to 2024.

# %% [markdown]
# ## Try reading in some data from Wikipedia - html
#
# Here we will explore academy award winning films. Go to the [Wiki for the List of Academy Award Winning Films](https://en.wikipedia.org/wiki/List_of_Academy_Award%E2%80%93winning_films). Look at what type of data is there. How many tables? Any weird looking data?
#
# Now read the html data into Python and show the data in DF[0]

# %%
# Your code here
DF[0]
# Out:
#                                                    Film  Year Awards  \
# 0                                           Oppenheimer  2023      7
# 1                                           Poor Things  2023      4
# 2                                  The Zone of Interest  2023      2
# 3                                      American Fiction  2023      1
# 4                                     Anatomy of a Fall  2023      1
# ...                                                 ...   ...    ...
# 1368                            The Yankee Doodle Mouse  1943      1
# 1369                                       The Yearling  1946      2
# 1370  Yesterday, Today and Tomorrow (Ieri, oggi, dom...  1964      1
# 1371                         You Can't Take It with You  1938      2
# 1372                    Zorba the Greek (Alexis Zorbas)  1964      3
#
#      Nominations
# 0             13
# 1             11
# 2              5
# 3              5
# 4              5
# ...          ...
# ...

# %%
# Here is some helper code
# This is code that will read in the data and then fix the Year column
my_website = "https://en.wikipedia.org/wiki/List_of_Academy_Award%E2%80%93winning_films"
DF = pd.read_html(my_website)
DF_raw = DF[0]
DF_raw['Year'] = DF_raw['Year'].apply(lambda x: int(x.split('/')[0]))
DF_raw['Year'].value_counts().reset_index().rename(columns={"index": "value", 0: "count"})
# Out:
#     Year  count
# 0   1945     21
# 1   1949     20
# 2   1942     20
# 3   1950     19
# 4   1948     19
# ..   ...    ...
# 91  1931     10
# 92  1932      9
# 93  1928      7
# 94  1929      6
# 95  1930      6
#
# [96 rows x 2 columns]

# %%
DF_raw.describe()
# Out:
#               Year  Nominations
# count  1373.000000  1373.000000
# mean   1975.864530     3.606701
# std      27.416755     3.125371
# min    1927.000000     0.000000
# 25%    1952.000000     1.000000
# 50%    1975.000000     2.000000
# 75%    2000.000000     5.000000
# max    2023.000000    14.000000

# %% [markdown]
# **Q4** Following along with the lecture notes or video, fix the data in the 'Awards' column.

# %%
# Your code here
my_columns = ['Year', 'Awards', 'Nominations']
DF_raw[my_columns].describe()
# Out:
#               Year  Nominations
# count  1373.000000  1373.000000
# mean   1975.864530     3.606701
# std      27.416755     3.125371
# min    1927.000000     0.000000
# 25%    1952.000000     1.000000
# 50%    1975.000000     2.000000
# 75%    2000.000000     5.000000
# max    2023.000000    14.000000

# %%
DF_raw.dtypes
# Out:
# Film           object
# Year            int64
# Awards         object
# Nominations     int64
# dtype: object

# %% [markdown]
# This code is only getting data from the columns 'Year', 'Awards', and 'Nominations'
# then (.describe()) is getting the data to be more descriptive and provides a summary

# %%
award_data = DF_raw['Awards'].value_counts()
DF_award = award_data.reset_index().rename(columns={"index": "value", 0: "count"})
DF_award
# Out:
#       Awards  count
# 0          1    979
# 1          2    156
# 2          3     77
# 3          4     47
# 4      0 (1)     32
# 5          5     25
# 6          7     12
# 7          6     12
# 8      1 (1)      8
# 9          8      7
# 10        11      3
# 11         9      3
# 12     0 (2)      3
# 13  0 (1)[1]      1
# 14     3 (1)      1
# 15     4 (1)      1
# 16     6 (1)      1
# 17     5 (1)      1
# 18     7 (1)      1
# 19     8 (2)      1
# 20     2 (1)      1
# 21        10      1

# %% [markdown]
# The graph is focusing only in the column 'Award' and ins counting all of them, but it is showing an error

# %% [markdown]
# **Q5** Now try to fix the data in the "Nominations" column - see if you can do it without looking at the answer.

# %%
# Your code here
nom_data = DF_raw['Nominations'].value_counts()
DF_nom = nom_data.reset_index().rename(columns={"index": "value", 0: "count"})
show(DF_nom)

print('I can see that I want the data to the left of the [ character')

DF_raw['Nominations'] = DF_raw['Nominations'].apply(lambda x: int(x.split('[')[0]))
award_data = DF_raw['Awards'].value_counts()
DF_award = award_data.reset_index().rename(columns={"index": "value", 0: "count"})
show(DF_award)

DF_raw.dtypes
# Out:
# <table id="itables_8cf35f9f_ffca_4920_bbcb_8dbf2a29ac24" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Nominations</th>
#       <th>count</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
# ...

# %% [markdown]
# ## Problem 1
#
# Your homework today will be to see if you can find some data of your own. This can be the first steps you take toward your final project.
#
# You should:
#
# * Find some data online
# * Read that data into Python using the Pandas commands we learned
# * Look at the DataFrame - number of variables, number of observations, AND the dtypes. Comment on what you see.
# * Try to do summary statistics (.describe()). Does it work like expected?
# * Attempt to fix any data, or explain why the data does not need to be fixed.
# * Make some sort of graph using columns in your data.

# %% [markdown]
# .describe() its suppused to give a summary of my data, my data is about mental health and the information given are just numbers then I need to find out how to make it look

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %%
DF_raw = pd.read_csv('Cancer_Rates.csv')
DF_raw
# Out:
#     OBJECTID    ZIP  Colorectal  Lung_Bronc  Breast_Can  Prostate_C  \
# 0          1  60002  218.062127  419.666735  399.094836  259.205925
# 1          2  60010  258.915706  335.464697  504.322767  499.819885
# 2          3  60015  153.435867  230.153801  478.573777  442.041428
# 3          4  60020  292.797189  507.515128  214.717939  302.557095
# 4          5  60030  221.535432  284.440555  404.780789  322.730629
# 5          6  60031  163.502110  221.518987  414.029536  303.270042
# 6          7  60035  241.311124  475.919161  553.004659  482.622248
# 7          8  60040   55.555556  240.740741  277.777778  185.185185
# 8          9  60042  140.252454  315.568022  397.381954  187.003273
# 9         10  60044  206.547558  237.529691  557.678405  413.095115
# 10        11  60045  258.334958  316.825892  609.280562  497.172938
# 11        12  60046  177.859376  258.182966  398.749247  275.395163
# 12        13  60047  198.953128  184.742190  362.378911  305.535160
# ...

# %%
DF_raw.shape
# Out:
# (27, 10)

# %% [markdown]
# Since this is the first data I'm going to work with in an assignment, I decided to choose one with little information so it wouldn't be so difficult, but even though there are few variables and few observations it is a good data to do this problem.
# My data has 27 observations and 10 variables

# %%
DF_raw.columns
# Out:
# Index(['OBJECTID', 'ZIP', 'Colorectal', 'Lung_Bronc', 'Breast_Can',
#        'Prostate_C', 'Urinary_Sy', 'All_Cancer', 'Shape__Area',
#        'Shape__Length'],
#       dtype='object')

# %% [markdown]
# Here I'm focusing on the columns so then later on, to do my graph I wont have a problem of misspeling

# %%
DF_raw.dtypes
# Out:
# OBJECTID           int64
# ZIP                int64
# Colorectal       float64
# Lung_Bronc       float64
# Breast_Can       float64
# Prostate_C       float64
# Urinary_Sy       float64
# All_Cancer       float64
# Shape__Area      float64
# Shape__Length    float64
# dtype: object

# %% [markdown]
# The data is mostly giving me float64 and then I have two int64, as far as I know both are numerical data.

# %%
DF_raw.describe()
# Out:
#         OBJECTID           ZIP  Colorectal  Lung_Bronc  Breast_Can  \
# count  27.000000     27.000000   27.000000   27.000000   27.000000
# mean   14.000000  60053.555556  215.662049  305.559073  392.842186
# std     7.937254     27.169459   77.162061  107.413853  122.334193
# min     1.000000  60002.000000   55.555556  182.810215  203.903701
# 25%     7.500000  60037.500000  175.618187  226.001013  292.531320
# 50%    14.000000  60047.000000  214.198286  280.606615  398.749247
# 75%    20.500000  60078.000000  249.823041  337.896841  482.168766
# max    27.000000  60099.000000  457.776172  578.243585  626.430551
#
#        Prostate_C  Urinary_Sy   All_Cancer   Shape__Area  Shape__Length
# count   27.000000   27.000000    27.000000  2.700000e+01      27.000000
# mean   320.079975  222.191454  2628.278959  4.695389e+08  146386.746889
# std    100.547764   87.796594   694.582068  2.938934e+08   54274.898427
# min    145.973430   56.610894  1465.294184  1.780943e+07   25907.372467
# ...

# %% [markdown]
# .describe() its supposed to give a summary of my data, my data is about cancer rates and the information given are just numbers, I think it is giving me the data I need.

# %%
columns=['All_Cancer', 'Colorectal']
DF_raw[columns].groupby('All_Cancer').sum()
# Out:
#              Colorectal
# All_Cancer
# 1465.294184  133.592080
# 1533.541086  103.329506
# 1796.296296   55.555556
# 1830.418921  188.702982
# 2092.970350  212.330325
# 2174.084908  184.467810
# 2205.740705  173.376999
# 2217.827004  163.502110
# 2261.907582  198.953128
# 2267.414680  140.252454
# 2317.369234  220.701832
# 2340.858889  177.859376
# 2409.730722  214.198286
# 2581.845035  221.535432
# 2596.584105  226.885990
# 2697.718891  276.601557
# 2703.147501  218.062127
# 2922.587952  153.435867
# 2991.535206  216.429396
# 2995.658466  303.907381
# 3084.130392  292.797189
# 3149.850253  206.547558
# 3200.462161  323.512421
# 3248.829251  258.915706
# 3611.815169  258.334958
# 3760.431679  241.311124
# 4505.481267  457.776172

# %% [markdown]
# Here I created a graph thats is showing all cancer in the column 'colorectal'

# %%
fig = px.scatter(DF_raw,x='Breast_Can',y='Lung_Bronc',title='Breast_can & Lung_Bronc')
fig.show()

# %% [markdown]
# Here my scartler is  showing me data about breast cancer and lung bronc, as it shows, the dot in the top, is saying that breats cancer is the most common

# %%
my_columns = ['All_Cancer']
DF_lead_time_sorted = DF_raw[my_columns].sort_values('All_Cancer', ascending=True)
show(DF_lead_time_sorted)
# Out:
# <table id="itables_5c09282a_f350_4117_ac5e_8ee9e63e074f" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>All_Cancer</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
# ...

# %% [markdown]
# Here I used sort_values so it will show me only the column 'All_cancer'

# %%
fig = px.bar(DF_raw,
            x='All_Cancer',
            color_discrete_sequence=['lightseagreen'])
fig.update_traces(dict(marker_line_width=0))
fig.show()

# %% [markdown]
# This is a bar plot is giving me the index (general information) about the column 'All_cancer'.

# %% [markdown]
# **What I am proud of this work is the data I found for problem 1,
# and that this task helped me a lot to locate more my errors in the code and how to fix them, it took me a while to have this task completed but I think it was very helpful to know more about python.**
